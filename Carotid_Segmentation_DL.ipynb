# %% [markdown]
# <a href="https://colab.research.google.com/github/SunkaraboinaPraveenKumar/Machine_Learning_Projects/blob/main/Carotid_Segmentation_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
orvile_carotid_ultrasound_images_path = kagglehub.dataset_download('orvile/carotid-ultrasound-images')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
! pip install kaggle

! mkdir ~/.kaggle

! cp /content/kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! kaggle datasets download orvile/carotid-ultrasound-images
# Out:
# Dataset URL: https://www.kaggle.com/datasets/orvile/carotid-ultrasound-images
# License(s): Attribution 4.0 International (CC BY 4.0)

# %%
! unzip /content/carotid-ultrasound-images.zip
# Out:
# Archive:  /content/carotid-ultrasound-images.zip
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1069.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1080.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1092.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1108.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1128.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1157.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1165.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1176.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1183.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1190.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1191.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1353.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1362.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1393.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1407.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1411.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1419.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1420.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1444.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1447.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1450.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1452.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1454.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1458.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1465.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1502.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1503.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1520.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1664.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1667.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1677.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1680.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1706.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1730.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1740.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1755.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1791.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1806.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1810.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1811.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1815.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1842.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1853.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1854.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1859.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1956.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1965.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_1978.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2067.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2247.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2269.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2272.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2276.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2292.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2295.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2318.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2319.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2320.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2324.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2336.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2342.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2368.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2376.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2378.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2410.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2412.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2423.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2447.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2451.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2454.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2459.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2468.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2503.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2504.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2506.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2608.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2627.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2630.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2652.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2689.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2733.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2894.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2909.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2918.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2919.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2949.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2952.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2956.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2958.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121748100022VAS_slice_2990.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_599.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_603.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_646.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_657.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_668.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_691.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_693.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_699.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_713.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121752220024VAS_slice_721.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1115.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1117.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1150.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1308.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1343.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1354.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1366.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1393.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1432.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_1446.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_253.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_261.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_359.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_380.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_409.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_468.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_496.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_514.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_521.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_534.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_541.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_547.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_560.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_609.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_621.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_630.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_635.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_640.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_655.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_694.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_729.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_750.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_755.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121805150026VAS_slice_782.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_103.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_113.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_158.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_24.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_26.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_297.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_36.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_370.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_396.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_54.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_56.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121806070027VAS_slice_82.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121807410028VAS_slice_693.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121807410028VAS_slice_700.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4687.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4699.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4705.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4710.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4736.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4764.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4767.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4774.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4813.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_4843.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5215.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5339.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5415.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5440.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5480.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5502.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5505.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5516.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5525.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5526.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5575.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5580.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5608.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5646.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5654.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5857.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5872.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_5942.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121808450029VAS_slice_6019.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_254.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_271.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_275.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_282.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_306.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_355.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_394.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_395.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_421.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_442.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_457.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_470.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_472.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_477.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_488.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_509.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_518.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_543.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_547.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_556.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_560.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_562.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121814260031VAS_slice_565.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1302.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1334.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1362.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1440.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1442.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1448.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1467.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1480.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1563.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1588.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1638.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1647.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1663.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1669.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1674.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1700.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1706.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1750.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1759.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1820.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1886.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1922.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1962.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_1982.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2036.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2121.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2127.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2150.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2183.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2211.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2247.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2301.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2377.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2380.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2382.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2398.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2431.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2446.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2457.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_2482.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_465.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_470.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_482.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_529.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_592.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121815070032VAS_slice_624.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1021.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1063.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1097.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1151.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1175.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1203.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1221.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1378.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1453.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1488.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1497.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1503.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1557.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1560.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_160.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1640.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1644.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_166.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_174.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1796.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_193.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1976.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_199.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1992.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_1997.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_2022.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_283.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_295.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_355.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_387.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_422.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_429.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_440.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_455.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_465.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_467.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_474.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_537.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_542.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_571.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_605.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_617.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_638.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_655.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_662.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_744.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_758.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_815.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_825.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_862.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_899.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_917.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_958.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121819140033VAS_slice_963.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_173.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_177.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_186.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_227.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_234.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_237.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_254.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_322.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_330.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_345.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_405.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_408.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_410.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_430.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_442.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_455.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823140034VAS_slice_479.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/Expert mask images/202201121823380035VAS_slice_1323.png
# ...
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071316520029VAS_slice_949.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071317290030VAS_slice_38.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_104.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_128.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_188.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_224.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_256.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_268.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_334.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_389.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_62.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_68.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071320220031VAS_slice_98.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_1013.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_1053.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_110.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_152.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_179.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_195.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_196.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_197.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_233.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_250.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_260.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_302.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_318.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_344.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_378.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_397.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_401.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_431.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_496.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_535.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_546.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_58.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_599.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_603.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_615.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_692.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_693.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_695.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_705.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_711.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_745.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_747.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_763.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_778.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_787.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_804.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_820.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_845.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_87.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_919.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_925.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355210050VAS_slice_984.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_102.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_143.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_145.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_147.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_184.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_188.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_200.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_22.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_274.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_3.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_308.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_313.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_333.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_340.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_351.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_356.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_375.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_411.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_418.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_428.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_436.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_444.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_489.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_499.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_524.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_549.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_580.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_622.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_643.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_669.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_672.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_673.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071355560051VAS_slice_75.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_1023.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_1036.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_233.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_548.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_557.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_580.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_593.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_783.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_794.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_864.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_867.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_914.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_916.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_935.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_949.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_954.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071357530054VAS_slice_960.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071358440055VAS_slice_183.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071358440055VAS_slice_191.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071359200056VAS_slice_111.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071359200056VAS_slice_117.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071359200056VAS_slice_180.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071359200056VAS_slice_214.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071359200056VAS_slice_227.png
#   inflating: Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202202071359200056VAS_slice_258.png
#   inflating: dataset.csv

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
base_path = "/content/Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/"
image_dir = base_path + "US images/"
mask_dir = base_path + "Expert mask images/"

# %%
print("Sample ultrasound images:", os.listdir(image_dir)[:5])
print("Sample masks:", os.listdir(mask_dir)[:5])
# Out:
# Sample ultrasound images: ['202201121858500045VAS_slice_1398.png', '202201121844200040VAS_slice_548.png', '202201121826590036VAS_slice_776.png', '202201121819140033VAS_slice_295.png', '202201121814260031VAS_slice_457.png']
# Sample masks: ['202201121858500045VAS_slice_1398.png', '202201121844200040VAS_slice_548.png', '202201121826590036VAS_slice_776.png', '202201121819140033VAS_slice_295.png', '202201121814260031VAS_slice_457.png']

# %%
print(f"Total images: {len(os.listdir(image_dir))}")
print(f"Total masks: {len(os.listdir(mask_dir))}")
# Out:
# Total images: 1100
# Total masks: 1100

# %%
image_files = sorted([os.path.join(image_dir, f) for f in os.listdir(image_dir)])
mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir)])

# %%
df = pd.DataFrame({"image_path": image_files, "mask_path": mask_files})

# %%
df.head()
# Out:
#                                           image_path  \
# 0  /content/Common Carotid Artery Ultrasound Imag...
# 1  /content/Common Carotid Artery Ultrasound Imag...
# 2  /content/Common Carotid Artery Ultrasound Imag...
# 3  /content/Common Carotid Artery Ultrasound Imag...
# 4  /content/Common Carotid Artery Ultrasound Imag...
#
#                                            mask_path
# 0  /content/Common Carotid Artery Ultrasound Imag...
# 1  /content/Common Carotid Artery Ultrasound Imag...
# 2  /content/Common Carotid Artery Ultrasound Imag...
# 3  /content/Common Carotid Artery Ultrasound Imag...
# 4  /content/Common Carotid Artery Ultrasound Imag...

# %%
print(df.shape)
print(df.columns)
print(df.duplicated().sum())
print(df.isnull().sum())
df.info()
# Out:
# (1100, 2)
# Index(['image_path', 'mask_path'], dtype='object')
# 0
# image_path    0
# mask_path     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  1100 non-null   object
#  1   mask_path   1100 non-null   object
# dtypes: object(2)
# memory usage: 17.3+ KB

# %%
import random

# %%
image_files = sorted(os.listdir(image_dir))
mask_files = sorted(os.listdir(mask_dir))

assert all(im.split('.')[0] == mk.split('.')[0] for im, mk in zip(image_files, mask_files)), "Mismatched files!"

fig, axes = plt.subplots(5, 2, figsize=(10, 25))

for idx in range(5):
    random_index = random.randint(0, len(image_files) - 1)
    img_path = os.path.join(image_dir, image_files[random_index])
    mask_path = os.path.join(mask_dir, mask_files[random_index])

    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    axes[idx, 0].imshow(img)
    axes[idx, 0].set_title(f"Ultrasound Image\n{image_files[random_index]}")
    axes[idx, 0].axis('off')

    axes[idx, 1].imshow(mask, cmap='gray')
    axes[idx, 1].set_title(f"Expert Mask\n{mask_files[random_index]}")
    axes[idx, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
image_files = [f for f in os.listdir(image_dir) if f.endswith('.png')]
mask_files = [f for f in os.listdir(mask_dir) if f.endswith('.png')]

# %%
missing_masks = [f for f in image_files if f not in mask_files]
if missing_masks:
    raise ValueError(f"Missing masks for {len(missing_masks)} images, including: {missing_masks[:3]}")

file_pairs = [(os.path.join(image_dir, f), os.path.join(mask_dir, f)) for f in image_files]

# %%
df = pd.DataFrame(file_pairs, columns=['image_path', 'mask_path'])

# %%
df.head()
# Out:
#                                           image_path  \
# 0  /content/Common Carotid Artery Ultrasound Imag...
# 1  /content/Common Carotid Artery Ultrasound Imag...
# 2  /content/Common Carotid Artery Ultrasound Imag...
# 3  /content/Common Carotid Artery Ultrasound Imag...
# 4  /content/Common Carotid Artery Ultrasound Imag...
#
#                                            mask_path
# 0  /content/Common Carotid Artery Ultrasound Imag...
# 1  /content/Common Carotid Artery Ultrasound Imag...
# 2  /content/Common Carotid Artery Ultrasound Imag...
# 3  /content/Common Carotid Artery Ultrasound Imag...
# 4  /content/Common Carotid Artery Ultrasound Imag...

# %%
def extract_subject_id(filename):
    """Extracts subject ID from filenames like:
    202201121748100022VAS_slice_1069.png
    202202071308300020EM VASCULAR_slice_695.png
    """
    parts = filename.split('_')
    if len(parts) < 3:
        raise ValueError(f"Unexpected filename format: {filename}")
    first_part = parts[0]
    timestamp_length = 18
    if len(first_part) < timestamp_length:
        raise ValueError(f"Unexpected first part length: {first_part}")
    identifier = first_part[timestamp_length:]
    subject_id = identifier.split()[0].strip()
    return subject_id

# %%
df['subject_id'] = df['image_path'].apply(lambda x: extract_subject_id(os.path.basename(x)))

print("Unique Subject IDs:", df['subject_id'].unique())
# Out:
# Unique Subject IDs: ['VAS' 'EM']

# %%
def unet(input_size=(256, 256, 3)):
    inputs = Input(input_size)

    c1 = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(32, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(64, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(p4)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    u8 = UpSampling2D((2, 2))(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same')(u8)
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same')(c8)

    u9 = UpSampling2D((2, 2))(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same')(u9)
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array # Import necessary functions

def load_data(df, image_size=(256, 256)):
    images = []
    masks = []
    for image_path, mask_path in zip(df['image_path'], df['mask_path']):
        img = load_img(image_path, target_size=image_size)
        img = img_to_array(img) / 255.0
        images.append(img)

        mask = load_img(mask_path, target_size=image_size, color_mode='grayscale')
        mask = img_to_array(mask) / 255.0
        masks.append(mask)

    return np.array(images), np.array(masks)

images, masks = load_data(df)
masks = np.expand_dims(masks, axis=-1)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=42)

# %%
# !apt-get install graphviz
# !pip install graphviz pydot
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (0.20.3)
# Requirement already satisfied: pydot in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.11/dist-packages (from pydot) (3.2.3)

# %%
from tensorflow.keras.utils import plot_model

model = unet()
plot_model(model, to_file="unet_architecture.png", show_layer_names=True)

# Display image inside notebook (optional)
from IPython.display import Image
Image("unet_architecture.png")

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(patience=10, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, verbose=1)

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=32, callbacks=[early_stopping, reduce_lr])

loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 256, 256, 3))
#   warnings.warn(msg)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8743 - loss: 0.4003 - val_accuracy: 0.9764 - val_loss: 0.0991 - learning_rate: 0.0010
# Epoch 2/5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 280ms/step - accuracy: 0.9767 - loss: 0.0872 - val_accuracy: 0.9764 - val_loss: 0.0649 - learning_rate: 0.0010
# Epoch 3/5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 288ms/step - accuracy: 0.9761 - loss: 0.0655 - val_accuracy: 0.9764 - val_loss: 0.0524 - learning_rate: 0.0010
# Epoch 4/5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - accuracy: 0.9767 - loss: 0.0525 - val_accuracy: 0.9764 - val_loss: 0.0390 - learning_rate: 0.0010
# Epoch 5/5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.9767 - loss: 0.0358 - val_accuracy: 0.9910 - val_loss: 0.0247 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 5.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9912 - loss: 0.0243
# Test Loss: 0.024746123701334, Test Accuracy: 0.9909502863883972

# %%
def plot_history(history):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    if 'val_accuracy' in history.history:
        plt.plot(history.history['val_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
    else:
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
    else:
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train'], loc='upper left')

    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
def calculate_iou(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    union = np.logical_or(y_true, y_pred).sum()
    if union == 0:
        return 0.0
    return intersection / union

def calculate_dice(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    total = y_true.sum() + y_pred.sum()
    if total == 0:
        return 0.0
    return 2 * intersection / total

# %%
y_pred_binary = (model.predict(X_test) > 0.5).astype(bool)
y_test_binary = y_test.astype(bool)

iou = calculate_iou(y_test_binary.squeeze(), y_pred_binary.squeeze())
dice = calculate_dice(y_test_binary.squeeze(), y_pred_binary.squeeze())

print(f"IoU: {iou}")
print(f"Dice: {dice}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 256, 256, 3))
#   warnings.warn(msg)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step
# IoU: 0.6258995693535716
# Dice: 0.7699117229023168

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │      9,248 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,887,877 (22.46 MB)
#  Trainable params: 1,962,625 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,925,252 (14.97 MB)

# %%
model.save("model.keras")

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Path to your real test image (change this to your image path)
real_image_path = "/content/Common Carotid Artery Ultrasound Images/Common Carotid Artery Ultrasound Images/US images/202201121748100022VAS_slice_2689.png"  # ← Update as needed

# Preprocess real input image
def preprocess_single_image(img_path, target_size=(256, 256)):
    img = load_img(img_path, target_size=target_size)
    img_array = img_to_array(img) / 255.0  # Normalize
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Test function for real image
def test_real_image(image_path):
    # Preprocess input image
    input_image = preprocess_single_image(image_path)

    # Predict using trained model
    prediction = model.predict(input_image)[0, :, :, 0]  # Get 2D prediction

    # Load original image for display
    img_show = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)
    img_show = cv2.resize(img_show, (256, 256))

    # Plot original image and predicted mask
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img_show)
    plt.title("Real Input Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(prediction > 0.5, cmap='gray')  # Show binary mask
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# 🔁 Run test
test_real_image(real_image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
