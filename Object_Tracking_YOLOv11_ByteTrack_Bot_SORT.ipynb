# %% [markdown]
# <a href="https://colab.research.google.com/github/SunkaraboinaPraveenKumar/Machine_Learning_Projects/blob/main/Object_Tracking_YOLOv11_ByteTrack_Bot_SORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.pt")

# Perform object detection on video
results = model("/content/1.mp4", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/291) /content/1.mp4: 384x640 (no detections), 72.2ms
# video 1/1 (frame 2/291) /content/1.mp4: 384x640 (no detections), 24.2ms
# video 1/1 (frame 3/291) /content/1.mp4: 384x640 (no detections), 24.2ms
# video 1/1 (frame 4/291) /content/1.mp4: 384x640 (no detections), 24.2ms
# video 1/1 (frame 5/291) /content/1.mp4: 384x640 (no detections), 24.1ms
# ...

# %%
results = model("/content/1.mp4",classes=0, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/291) /content/1.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (frame 2/291) /content/1.mp4: 384x640 (no detections), 11.9ms
# video 1/1 (frame 3/291) /content/1.mp4: 384x640 (no detections), 12.5ms
# video 1/1 (frame 4/291) /content/1.mp4: 384x640 (no detections), 16.6ms
# video 1/1 (frame 5/291) /content/1.mp4: 384x640 (no detections), 12.6ms
# ...

# %%
results = model.track(source="/content/1.mp4", persist=True, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/291) /content/1.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (frame 2/291) /content/1.mp4: 384x640 (no detections), 16.4ms
# video 1/1 (frame 3/291) /content/1.mp4: 384x640 (no detections), 14.1ms
# video 1/1 (frame 4/291) /content/1.mp4: 384x640 (no detections), 15.2ms
# video 1/1 (frame 5/291) /content/1.mp4: 384x640 (no detections), 16.1ms
# ...

# %%
results = model.track("/content/1.mp4", persist=True, show=True, classes=0, tracker="bytetrack.yaml")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
