# %% [markdown]
# <a href="https://colab.research.google.com/github/SunkaraboinaPraveenKumar/Machine_Learning_Projects/blob/main/Satellite_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install split-folders

# %%
# !pip install keras

# %%
# !pip install --upgrade tensorflow

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Activation
from tensorflow.keras import models
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.utils import plot_model
from PIL import Image
import splitfolders

# %%
#unzip data folder
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/green_area/Forest_936.jpg
#   inflating: data/green_area/Forest_98.jpg
#   inflating: data/green_area/Forest_986.jpg
#   inflating: data/green_area/Forest_977.jpg
#   inflating: data/green_area/Forest_925.jpg
#   inflating: data/green_area/Forest_984.jpg
#   inflating: data/green_area/Forest_928.jpg
#   inflating: data/green_area/Forest_93.jpg
#   inflating: data/green_area/Forest_923.jpg
#   inflating: data/green_area/Forest_970.jpg
#   inflating: data/green_area/Forest_978.jpg
#   inflating: data/green_area/Forest_995.jpg
#   inflating: data/green_area/Forest_960.jpg
#   inflating: data/green_area/Forest_954.jpg
#   inflating: data/green_area/Forest_975.jpg
#   inflating: data/green_area/Forest_956.jpg
#   inflating: data/green_area/Forest_99.jpg
#   inflating: data/green_area/Forest_961.jpg
#   inflating: data/green_area/Forest_924.jpg
#   inflating: data/green_area/Forest_981.jpg
# ...

# %%
#Split data in train,test,validation
input_folder="/content/data"
output="dataset"
splitfolders.ratio(input_folder, output=output, seed=42, ratio=(0.7, 0.2,0.1))
# Out:
# Copying files: 5020 files [00:00, 5974.19 files/s]

# %%
#Data Argumentation
train_datagen=ImageDataGenerator(rescale=1./255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 horizontal_flip=True)
training_set=train_datagen.flow_from_directory("/content/dataset/train",
                                                 target_size=(224,224),
                                                 batch_size=32,
                                                 class_mode="categorical")
# Out:
# Found 3513 images belonging to 4 classes.

# %%
test_datagen=ImageDataGenerator(rescale=1./255)
test_set=test_datagen.flow_from_directory("/content/dataset/test",
                                                 target_size=(224,224),
                                                 batch_size=32,
                                                 class_mode="categorical")
# Out:
# Found 504 images belonging to 4 classes.

# %%
val_datagen=ImageDataGenerator(rescale=1./255)
val_set=val_datagen.flow_from_directory("/content/dataset/val",
                                                 target_size=(224,224),
                                                 batch_size=32,
                                                 class_mode="categorical")
# Out:
# Found 1003 images belonging to 4 classes.

# %%
training_set.class_indices
# Out:
# {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}

# %%
#Creating Base Model with VGG16
base_model=VGG16(input_shape=(224,224,3),
                 include_top=False,
                 weights="imagenet")
base_model.trainable=False
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
#Adding layers to VGG16
flatten_layer=Flatten()
dense_layer_1=Dense(50,activation='relu')
dense_layer_2=Dense(20,activation='relu')
prediction_layer=Dense(4,activation='softmax')

# %%
model=models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16

# Data Augmentation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory("/content/dataset/train",
                                                 target_size=(224, 224),
                                                 batch_size=32,
                                                 class_mode="categorical")

test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory("/content/dataset/test",
                                            target_size=(224, 224),
                                            batch_size=32,
                                            class_mode="categorical")

val_datagen = ImageDataGenerator(rescale=1./255)

val_set = val_datagen.flow_from_directory("/content/dataset/val",
                                          target_size=(224, 224),
                                          batch_size=32,
                                          class_mode="categorical")

# Creating Base Model with VGG16
base_model = VGG16(input_shape=(224, 224, 3),
                   include_top=False,
                   weights="imagenet")
base_model.trainable = False

# Adding layers to VGG16
flatten_layer = Flatten()
dense_layer_1 = Dense(50, activation='relu')
dense_layer_2 = Dense(20, activation='relu')
prediction_layer = Dense(4, activation='softmax')

# Correct Sequential model construction
model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
])

# Compiling the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Training the model
history = model.fit(x=training_set, validation_data=test_set, epochs=5)
# Out:
# Found 3513 images belonging to 4 classes.
# Found 504 images belonging to 4 classes.
# Found 1003 images belonging to 4 classes.
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 92s 674ms/step - accuracy: 0.5298 - loss: 1.1197 - val_accuracy: 0.9583 - val_loss: 0.3878
# Epoch 2/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 48s 419ms/step - accuracy: 0.9208 - loss: 0.3073 - val_accuracy: 0.9782 - val_loss: 0.1267
# Epoch 3/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 50s 437ms/step - accuracy: 0.9648 - loss: 0.1418 - val_accuracy: 0.9802 - val_loss: 0.0749
# Epoch 4/5
# ...

# %%
accuracy=model.evaluate(val_set,verbose=1)
print("Accuracy: ",accuracy[1])

# %%
model.save('best_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16

# Data Augmentation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory("/content/dataset/train",
                                                 target_size=(224, 224),
                                                 batch_size=32,
                                                 class_mode="categorical")

test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory("/content/dataset/test",
                                            target_size=(224, 224),
                                            batch_size=32,
                                            class_mode="categorical")

val_datagen = ImageDataGenerator(rescale=1./255)

val_set = val_datagen.flow_from_directory("/content/dataset/val",
                                          target_size=(224, 224),
                                          batch_size=32,
                                          class_mode="categorical")

# Creating Base Model with VGG16
base_model = VGG16(input_shape=(224, 224, 3),
                   include_top=False,
                   weights="imagenet")
base_model.trainable = False

# Adding layers to VGG16
flatten_layer = Flatten()
dense_layer_1 = Dense(50, activation='relu')
dense_layer_2 = Dense(20, activation='relu')
prediction_layer = Dense(4, activation='softmax')

# Correct Sequential model construction
model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    dense_layer_2,
    prediction_layer
])

# Compiling the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Training the model
history = model.fit(x=training_set, validation_data=test_set, epochs=5)
accuracy = model.evaluate(val_set, verbose=1)
print("Accuracy: ", accuracy[1])

# Saving the model
model.save('best_model.h5')

# Loading and testing the saved model
from tensorflow.keras.models import load_model
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import preprocess_input

model = load_model('/content/best_model.h5')

img_path = '/content/dataset/val/cloudy/train_10021.jpg'
img = tf.keras.utils.load_img(img_path, target_size=(224, 224))
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
predicted_class_index = np.argmax(preds)
print('predicted_class_index', predicted_class_index)
# Out:
# Found 3513 images belonging to 4 classes.
# Found 504 images belonging to 4 classes.
# Found 1003 images belonging to 4 classes.
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 53s 439ms/step - accuracy: 0.4902 - loss: 1.1494 - val_accuracy: 0.9663 - val_loss: 0.2947
# Epoch 2/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - accuracy: 0.9108 - loss: 0.3096 - val_accuracy: 0.9187 - val_loss: 0.2524
# Epoch 3/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 84s 424ms/step - accuracy: 0.9591 - loss: 0.1678 - val_accuracy: 0.9663 - val_loss: 0.1071
# Epoch 4/5
# ...
