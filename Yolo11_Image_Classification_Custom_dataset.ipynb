# %% [markdown]
# <a href="https://colab.research.google.com/github/SunkaraboinaPraveenKumar/Machine_Learning_Projects/blob/main/Yolo11_Image_Classification_Custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 22.8 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="zFQ2ciro7ThDLQIDJEQL")
project = rf.workspace("poultrydiseasedetection").project("fowl-pox")
version = project.version(1)
dataset = version.download("folder")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Fowl-pox-1 in folder:: 100%|██████████| 934/934 [00:00<00:00, 1177.70it/s]

# %%
# !unzip "/content/Fowl-pox.v1i.folder.zip"
# Out:
# Archive:  /content/Fowl-pox.v1i.folder.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#    creating: test/
#    creating: test/fowlpox/
#  extracting: test/fowlpox/101_jpg.rf.3c9adf31729e9b90447f4571ad7152e5.jpg
#  extracting: test/fowlpox/109_jpg.rf.bba93bb986f2007560040b6481dfa6fb.jpg
#  extracting: test/fowlpox/110_jpg.rf.af094ef90bc7f1c1a0dce527610bfcdc.jpg
#  extracting: test/fowlpox/127_jpg.rf.090045d8a4a48062caaf4b0f0bc9e642.jpg
#  extracting: test/fowlpox/144_jpg.rf.6198064a1f708cd7f1b926dcf8bcc8bf.jpg
#  extracting: test/fowlpox/14_jpg.rf.d89db685b07a856640f9b7462537a593.jpg
#  extracting: test/fowlpox/160_jpg.rf.292bfc63a4cac2128f127b621a72470b.jpg
#  extracting: test/fowlpox/180_jpg.rf.4b21f52939e55f566267ca44d3fa6362.jpg
#  extracting: test/fowlpox/184_jpg.rf.023bddf4bf925604a22520d992b94c08.jpg
#  extracting: test/fowlpox/19_jpg.rf.27eea582f71b6a5d50e953b2b4ddd25e.jpg
#  extracting: test/fowlpox/205_jpg.rf.d9f7a2f2b6abf95d9ccb418d9faf4035.jpg
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolo11n-cls.pt')

results = model.train(
    data='/content',
    epochs=10,
    imgsz=640
)
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image
Image("/content/runs/classify/train3/results.png", width=600)

# %%
results = model("/content/h.png") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/h.png: 640x640 fowlpox 1.00, 5.4ms
# Speed: 18.1ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=265x190>

# %%
results = model("/content/d.png", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/d.png: 640x640 fowlpox 1.00, 11.6ms
# Speed: 45.8ms preprocess, 11.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/train32
# <PIL.Image.Image image mode=RGB size=259x194>
