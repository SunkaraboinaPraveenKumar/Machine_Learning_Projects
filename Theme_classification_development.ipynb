# %% [markdown]
# <a href="https://colab.research.google.com/github/SunkaraboinaPraveenKumar/Machine_Learning_Projects/blob/main/Theme_classification_development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
from nltk import sent_tokenize
import nltk
import torch

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Load Model
model_name="facebook/bart-large-mnli"
device = 0 if torch.cuda.is_available() else 'cpu'

# %%
def load_model(device):
    theme_classifier=pipeline(
        "zero-shot-classification",
        model=model_name,
        device=device
    )
    return theme_classifier

# %%
theme_classifier=load_model(device)

# %%
theme_list=["friendship","hope","sacrifice","battle","self development","betrayal","love","dialogue"]

# %%
theme_classifier(
    "I gave him a right hook then a left jab",
    theme_list,
    multi_label=True
)
# Out:
# {'sequence': 'I gave him a right hook then a left jab',
#  'labels': ['battle',
#   'self development',
#   'hope',
#   'sacrifice',
#   'dialogue',
#   'betrayal',
#   'love',
#   'friendship'],
#  'scores': [0.9121255278587341,
#   0.4749981760978699,
#   0.0878177061676979,
#   0.04499982297420502,
#   0.020132659003138542,
#   0.012040399014949799,
#   0.004292286932468414,
#   0.0028172098100185394]}

# %%
# !unzip /content/subtitles.zip
# Out:
# Archive:  /content/subtitles.zip
#    creating: subtitles/
#   inflating: subtitles/Naruto Season 1 - 01.ass
#   inflating: subtitles/Naruto Season 1 - 02.ass
#   inflating: subtitles/Naruto Season 1 - 03.ass
#   inflating: subtitles/Naruto Season 1 - 04.ass
#   inflating: subtitles/Naruto Season 1 - 05.ass
#   inflating: subtitles/Naruto Season 1 - 06.ass
#   inflating: subtitles/Naruto Season 1 - 07.ass
#   inflating: subtitles/Naruto Season 1 - 08.ass
#   inflating: subtitles/Naruto Season 1 - 09.ass
#   inflating: subtitles/Naruto Season 1 - 10.srt
#   inflating: subtitles/Naruto Season 1 - 11.srt
#   inflating: subtitles/Naruto Season 1 - 12.ass
#   inflating: subtitles/Naruto Season 1 - 13.ass
#   inflating: subtitles/Naruto Season 1 - 14.ass
#   inflating: subtitles/Naruto Season 1 - 15.ass
#   inflating: subtitles/Naruto Season 1 - 16.ass
#   inflating: subtitles/Naruto Season 1 - 17.ass
#   inflating: subtitles/Naruto Season 1 - 18.ass
#   inflating: subtitles/Naruto Season 1 - 19.ass
#   inflating: subtitles/Naruto Season 1 - 20.ass
#   inflating: subtitles/Naruto Season 1 - 21.ass
#   inflating: subtitles/Naruto Season 1 - 22.ass
#   inflating: subtitles/Naruto Season 1 - 23.ass
#   inflating: subtitles/Naruto Season 1 - 24.ass
#   inflating: subtitles/Naruto Season 1 - 25.ass
#   inflating: subtitles/Naruto Season 1 - 26.ass
#   inflating: subtitles/Naruto Season 2 - 27.ass
#   inflating: subtitles/Naruto Season 2 - 28.ass
#   inflating: subtitles/Naruto Season 2 - 29.ass
#   inflating: subtitles/Naruto Season 2 - 30.ass
#   inflating: subtitles/Naruto Season 2 - 31.ass
#   inflating: subtitles/Naruto Season 2 - 32.ass
#   inflating: subtitles/Naruto Season 2 - 33.ass
#   inflating: subtitles/Naruto Season 2 - 34.ass
#   inflating: subtitles/Naruto Season 2 - 35.ass
#   inflating: subtitles/Naruto Season 2 - 36.ass
#   inflating: subtitles/Naruto Season 2 - 37.ass
#   inflating: subtitles/Naruto Season 2 - 38.ass
#   inflating: subtitles/Naruto Season 2 - 39.ass
#   inflating: subtitles/Naruto Season 2 - 40.ass
#   inflating: subtitles/Naruto Season 2 - 41.ass
#   inflating: subtitles/Naruto Season 2 - 42.ass
#   inflating: subtitles/Naruto Season 2 - 43.ass
#   inflating: subtitles/Naruto Season 2 - 44.ass
#   inflating: subtitles/Naruto Season 2 - 45.ass
#   inflating: subtitles/Naruto Season 2 - 46.ass
#   inflating: subtitles/Naruto Season 2 - 47.ass
#   inflating: subtitles/Naruto Season 2 - 48.ass
#   inflating: subtitles/Naruto Season 2 - 49.ass
#   inflating: subtitles/Naruto Season 2 - 50.ass
#   inflating: subtitles/Naruto Season 2 - 51.ass
#   inflating: subtitles/Naruto Season 2 - 52.ass
#   inflating: subtitles/Naruto Season 3 - 53.ass
#   inflating: subtitles/Naruto Season 3 - 54.ass
#   inflating: subtitles/Naruto Season 3 - 55.ass
#   inflating: subtitles/Naruto Season 3 - 56.ass
#   inflating: subtitles/Naruto Season 3 - 57.ass
#   inflating: subtitles/Naruto Season 3 - 58.ass
#   inflating: subtitles/Naruto Season 3 - 59.ass
#   inflating: subtitles/Naruto Season 3 - 60.ass
#   inflating: subtitles/Naruto Season 3 - 61.ass
#   inflating: subtitles/Naruto Season 3 - 62.ass
#   inflating: subtitles/Naruto Season 3 - 63.ass
#   inflating: subtitles/Naruto Season 3 - 64.ass
#   inflating: subtitles/Naruto Season 3 - 65.ass
#   inflating: subtitles/Naruto Season 3 - 66.ass
#   inflating: subtitles/Naruto Season 3 - 67.ass
#   inflating: subtitles/Naruto Season 3 - 68.ass
#   inflating: subtitles/Naruto Season 3 - 69.ass
#   inflating: subtitles/Naruto Season 3 - 70.ass
#   inflating: subtitles/Naruto Season 3 - 71.ass
#   inflating: subtitles/Naruto Season 3 - 72.ass
#   inflating: subtitles/Naruto Season 3 - 73.ass
#   inflating: subtitles/Naruto Season 3 - 74.ass
#   inflating: subtitles/Naruto Season 3 - 75.ass
#   inflating: subtitles/Naruto Season 3 - 76.ass
#   inflating: subtitles/Naruto Season 3 - 77.ass
#   inflating: subtitles/Naruto Season 3 - 78.ass
#   inflating: subtitles/Naruto Season 4 - 100.ass
#   inflating: subtitles/Naruto Season 4 - 101.ass
#   inflating: subtitles/Naruto Season 4 - 102.ass
#   inflating: subtitles/Naruto Season 4 - 103.ass
#   inflating: subtitles/Naruto Season 4 - 104.ass
#   inflating: subtitles/Naruto Season 4 - 79.ass
#   inflating: subtitles/Naruto Season 4 - 80.ass
#   inflating: subtitles/Naruto Season 4 - 81.ass
#   inflating: subtitles/Naruto Season 4 - 82.ass
#   inflating: subtitles/Naruto Season 4 - 83.ass
#   inflating: subtitles/Naruto Season 4 - 84.ass
#   inflating: subtitles/Naruto Season 4 - 85.ass
#   inflating: subtitles/Naruto Season 4 - 86.ass
#   inflating: subtitles/Naruto Season 4 - 87.ass
#   inflating: subtitles/Naruto Season 4 - 88.ass
#   inflating: subtitles/Naruto Season 4 - 89.ass
#   inflating: subtitles/Naruto Season 4 - 90.ass
#   inflating: subtitles/Naruto Season 4 - 91.ass
#   inflating: subtitles/Naruto Season 4 - 92.ass
#   inflating: subtitles/Naruto Season 4 - 93.ass
#   inflating: subtitles/Naruto Season 4 - 94.ass
#   inflating: subtitles/Naruto Season 4 - 95.ass
#   inflating: subtitles/Naruto Season 4 - 96.ass
#   inflating: subtitles/Naruto Season 4 - 97.ass
#   inflating: subtitles/Naruto Season 4 - 98.ass
#   inflating: subtitles/Naruto Season 4 - 99.ass
#   inflating: subtitles/Naruto Season 5 - 105.ass
#   inflating: subtitles/Naruto Season 5 - 106.ass
#   inflating: subtitles/Naruto Season 5 - 107.ass
#   inflating: subtitles/Naruto Season 5 - 108.ass
#   inflating: subtitles/Naruto Season 5 - 109.ass
#   inflating: subtitles/Naruto Season 5 - 110.ass
#   inflating: subtitles/Naruto Season 5 - 111.ass
#   inflating: subtitles/Naruto Season 5 - 112.ass
#   inflating: subtitles/Naruto Season 5 - 113.ass
#   inflating: subtitles/Naruto Season 5 - 114.ass
#   inflating: subtitles/Naruto Season 5 - 115.ass
#   inflating: subtitles/Naruto Season 5 - 116.ass
#   inflating: subtitles/Naruto Season 5 - 117.ass
#   inflating: subtitles/Naruto Season 5 - 118.ass
#   inflating: subtitles/Naruto Season 5 - 119.ass
#   inflating: subtitles/Naruto Season 5 - 120.ass
#   inflating: subtitles/Naruto Season 5 - 121.ass
#   inflating: subtitles/Naruto Season 5 - 122.ass
#   inflating: subtitles/Naruto Season 5 - 123.ass
#   inflating: subtitles/Naruto Season 5 - 124.ass
#   inflating: subtitles/Naruto Season 5 - 125.ass
#   inflating: subtitles/Naruto Season 5 - 126.ass
#   inflating: subtitles/Naruto Season 5 - 127.ass
#   inflating: subtitles/Naruto Season 5 - 128.ass
#   inflating: subtitles/Naruto Season 5 - 129.ass
#   inflating: subtitles/Naruto Season 5 - 130.ass
#   inflating: subtitles/Naruto Season 6 - 131.ass
#   inflating: subtitles/Naruto Season 6 - 132.ass
#   inflating: subtitles/Naruto Season 6 - 133.ass
#   inflating: subtitles/Naruto Season 6 - 134.ass
#   inflating: subtitles/Naruto Season 6 - 135.ass
#   inflating: subtitles/Naruto Season 6 - 136.ass
#   inflating: subtitles/Naruto Season 6 - 137.ass
#   inflating: subtitles/Naruto Season 6 - 138.ass
#   inflating: subtitles/Naruto Season 6 - 139.ass
#   inflating: subtitles/Naruto Season 6 - 140.ass
#   inflating: subtitles/Naruto Season 6 - 141.ass
#   inflating: subtitles/Naruto Season 6 - 142.ass
#   inflating: subtitles/Naruto Season 6 - 143.ass
#   inflating: subtitles/Naruto Season 6 - 144.ass
#   inflating: subtitles/Naruto Season 6 - 145.ass
#   inflating: subtitles/Naruto Season 6 - 146.ass
#   inflating: subtitles/Naruto Season 6 - 147.ass
#   inflating: subtitles/Naruto Season 6 - 148.ass
#   inflating: subtitles/Naruto Season 6 - 149.ass
#   inflating: subtitles/Naruto Season 6 - 150.ass
#   inflating: subtitles/Naruto Season 6 - 151.ass
#   inflating: subtitles/Naruto Season 6 - 152.ass
#   inflating: subtitles/Naruto Season 6 - 153.ass
#   inflating: subtitles/Naruto Season 6 - 154.ass
#   inflating: subtitles/Naruto Season 6 - 155.ass
#   inflating: subtitles/Naruto Season 6 - 156.ass
#   inflating: subtitles/Naruto Season 7 - 157.ass
#   inflating: subtitles/Naruto Season 7 - 158.ass
#   inflating: subtitles/Naruto Season 7 - 159.ass
#   inflating: subtitles/Naruto Season 7 - 160.ass
#   inflating: subtitles/Naruto Season 7 - 161.ass
#   inflating: subtitles/Naruto Season 7 - 162.ass
#   inflating: subtitles/Naruto Season 7 - 163.ass
#   inflating: subtitles/Naruto Season 7 - 164.ass
#   inflating: subtitles/Naruto Season 7 - 165.ass
#   inflating: subtitles/Naruto Season 7 - 166.ass
#   inflating: subtitles/Naruto Season 7 - 167.ass
#   inflating: subtitles/Naruto Season 7 - 168.ass
#   inflating: subtitles/Naruto Season 7 - 169.ass
#   inflating: subtitles/Naruto Season 7 - 170.ass
#   inflating: subtitles/Naruto Season 7 - 171.ass
#   inflating: subtitles/Naruto Season 7 - 172.ass
#   inflating: subtitles/Naruto Season 7 - 173.ass
#   inflating: subtitles/Naruto Season 7 - 174.ass
#   inflating: subtitles/Naruto Season 7 - 175.ass
#   inflating: subtitles/Naruto Season 7 - 176.ass
#   inflating: subtitles/Naruto Season 7 - 177.ass
#   inflating: subtitles/Naruto Season 7 - 178.ass
#   inflating: subtitles/Naruto Season 7 - 179.ass
#   inflating: subtitles/Naruto Season 7 - 180.ass
#   inflating: subtitles/Naruto Season 7 - 181.ass
#   inflating: subtitles/Naruto Season 7 - 182.ass
#   inflating: subtitles/Naruto Season 8 - 183.ass
#   inflating: subtitles/Naruto Season 8 - 184.ass
#   inflating: subtitles/Naruto Season 8 - 185.ass
#   inflating: subtitles/Naruto Season 8 - 186.ass
#   inflating: subtitles/Naruto Season 8 - 187.ass
#   inflating: subtitles/Naruto Season 8 - 188.ass
#   inflating: subtitles/Naruto Season 8 - 189.ass
#   inflating: subtitles/Naruto Season 8 - 190.ass
#   inflating: subtitles/Naruto Season 8 - 191.ass
#   inflating: subtitles/Naruto Season 8 - 192.ass
#   inflating: subtitles/Naruto Season 8 - 193.ass
#   inflating: subtitles/Naruto Season 8 - 194.ass
#   inflating: subtitles/Naruto Season 8 - 195.ass
#   inflating: subtitles/Naruto Season 8 - 196.ass
#   inflating: subtitles/Naruto Season 8 - 197.ass
#   inflating: subtitles/Naruto Season 8 - 198.ass
#   inflating: subtitles/Naruto Season 8 - 199.ass
#   inflating: subtitles/Naruto Season 8 - 200.ass
#   inflating: subtitles/Naruto Season 8 - 201.ass
#   inflating: subtitles/Naruto Season 8 - 202.ass
#   inflating: subtitles/Naruto Season 8 - 203.ass
#   inflating: subtitles/Naruto Season 8 - 204.ass
#   inflating: subtitles/Naruto Season 8 - 205.ass
#   inflating: subtitles/Naruto Season 8 - 206.ass
#   inflating: subtitles/Naruto Season 8 - 207.ass
#   inflating: subtitles/Naruto Season 8 - 208.ass
#   inflating: subtitles/Naruto Season 9 - 209.ass
#   inflating: subtitles/Naruto Season 9 - 210.ass
#   inflating: subtitles/Naruto Season 9 - 211.ass
#   inflating: subtitles/Naruto Season 9 - 212.ass
#   inflating: subtitles/Naruto Season 9 - 213.ass
#   inflating: subtitles/Naruto Season 9 - 214.ass
#   inflating: subtitles/Naruto Season 9 - 215.ass
#   inflating: subtitles/Naruto Season 9 - 216.ass
#   inflating: subtitles/Naruto Season 9 - 217.ass
#   inflating: subtitles/Naruto Season 9 - 218.ass
#   inflating: subtitles/Naruto Season 9 - 219.ass
#   inflating: subtitles/Naruto Season 9 - 220.ass

# %%
#Load dataset
from glob import glob
files=glob("/content/subtitles/*.ass")

# %%
files[:5]
# Out:
# ['/content/subtitles/Naruto Season 3 - 62.ass',
#  '/content/subtitles/Naruto Season 5 - 114.ass',
#  '/content/subtitles/Naruto Season 4 - 97.ass',
#  '/content/subtitles/Naruto Season 1 - 01.ass',
#  '/content/subtitles/Naruto Season 3 - 55.ass']

# %%
with open(files[0],'r') as file:
  lines=file.readlines()
  lines=lines[27:]
  lines=[",".join(line.split(",")[9:]) for line in lines ]

# %%
lines[:2]
# Out:
# ['Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength\n',
#  'Even if you get lost, let’s start walking\n']

# %%
#replace \n with space
lines=[line.replace("\n"," ") for line in lines]

# %%
lines[:2]
# Out:
# ['Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength ',
#  'Even if you get lost, let’s start walking ']

# %%
" ".join(lines[:10])
# Out:
# "Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength  Even if you get lost, let’s start walking  One more time  Are you really happy  when you're always meeting\\Nto someone's expectations?  Even if you change to\\Nwho you really wanna be  Will you always have a great smile?  Dreaming of only “the beginning,”\\NI wake up  and someday, I'll live on my own.  Yes, precious things are never in shape "

# %%
int(files[0].split('-')[-1].split('.')[0].strip())
# Out:
# 62

# %%
import pandas as pd

# %%
def load_subtitles_dataset(dataset_path):
  subtitles_paths=glob('/content/subtitles/*.ass')
  scripts=[]
  episodes=[]
  for path in subtitles_paths:
    with open(path,'r') as file:
      lines=file.readlines()
      lines=lines[27:]
      lines=[",".join(line.split(",")[9:]) for line in lines ]
      lines=[line.replace("\n"," ") for line in lines]
      script=" ".join(lines)
      episode=int(path.split('-')[-1].split('.')[0].strip())
      scripts.append(script)
      episodes.append(episode)
  df=pd.DataFrame.from_dict({
      "episode":episodes,
      "script":scripts
  })
  return df

# %%
dataset_path='/content/subtitles'
df=load_subtitles_dataset(dataset_path)

# %%
df.head()
# Out:
#    episode                                             script
# 0       62  Yeah, turn your sadness into kindness,\Nyour u...
# 1      114  Connecting old words\Nthat have been used up  ...
# 2       97  We are Fighting Dreamers aiming high  Fighting...
# 3        1  A long time ago, a powerful demon fox\Nappeare...
# 4       55  Yeah, turn your sadness into kindness,\Nyour u...

# %%
# Run Model
script=df.iloc[0]['script']

# %%
script
# Out:
# 'Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength  Even if you get lost, let’s start walking  One more time  Are you really happy  when you\'re always meeting\\Nto someone\'s expectations?  Even if you change to\\Nwho you really wanna be  Will you always have a great smile?  Dreaming of only “the beginning,”\\NI wake up  and someday, I\'ll live on my own.  Yes, precious things are never in shape  You never know what it is\\Nwhen you get it or lose it  Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength  Even if you get lost,\\Nlet\'s start walking  One more time  Your destiny is to lose to me.\\NFor sure.  You don’t know until you try!  Your father was killed a long time ago  and I don’t know the extent\\Nof the pain you’ve felt…  But it’s a huge mistake for you to think\\Nthat has determined your entire destiny!  You’re hopeless…  Proctor…it’s over.  You failure…  A Failure\'s True Power  Don’t…run away.  I won’t…run…  I’ll…stand by my own words…  That’s my Ninja Way!  I’ll…  stand…  by my own…  words!  That’s my…Ninja Way…  I think I’ve heard that line before…  You with your destiny stuff…  I won’t lose…  to a jerk with cold feet like you,\\Nno matter what!  Naruto…  A brat who knows nothing\\Nshouldn’t lecture arrogantly!  People are born burdened with\\Nan inherent destiny that they cannot defy.  Neji…live…  You’re a man who is blessed\\Nwith Hyuga ability  more than anyone in the family…  I wanted you…to be born\\Ninto the head family…  You can’t possibly understand  the destiny of being burdened with\\Na mark that cannot be wiped off for life!  Yeah…  I do understand it.  So…what of it?  This brat!  Don’t be acting cool…  It’s not just you who’s special!  Hinata was also…\\Nsuffering the same as you!  Even though she’s the head family,\\Nnot being acknowledged as such…  trying desperately to change herself…  She fought you while coughing\\Nup blood with that in mind!  You too!  The branch family that\\Nprotects the head family…  Doing all that to Hinata\\Njust because it’s an exam.  In actuality, you were just as frantic  in attempting to go\\Nagainst destiny, right?  Vitality has returned to Hinata’s face!  Just what I’d expect of\\Nthe Anbu Black Ops…  She\'ll be okay.  Now she needs bed rest.  Your 64 Chakra Points are now shut…  How are you, who can’t use Chakra\\Nfor awhile, planning to fight?  At the end of the day,  you and Miss Hinata have\\Nthe same destiny!  Shut up!  With your Byakugan, labeling people\\Nand talking like you understand!  Then…show me whether what\\Nyou’re saying is true or not.  I will! I’ll defeat you no matter\\Nwhat and prove that to you!  Dang it… Dang it!  That being said, I don’t feel Chakra at all.  It feels like when I used up\\Nmy Chakra in the training.  You possess two kinds of Chakra…  You must extract and utilize, at any time,  the other huge Chakra that\\Nhas rested inside you from the start…  That’s it. The Nine-Tailed Fox Chakra…\\NI’ll use that…  Stinking fox… \t\t\t\t\tHelp me out!  This is as far as the talking goes.  Proctor… I’m going to fight with\\Nthe intent to kill him!  If you’re going to stop me,\\Nplease feel free.  Jeez.  Didn’t I tell you it is pointless?  This time, I really can’t lose!  I’ll win no matter what!  It’s futile…I pressed the Chakra Points…  No matter what…  Oh, yeah! Be sure to come\\Nwatch me kick that Neji’s butt!  A failure beats down\\Na genius with effort…  His opponent might be me…  But even if that’s you, Naruto,\\Nno hard feelings.  Why do you try to go against\\Nyour destiny that much?  Because I was called…  a failure!  No, no way! Chakra is seeping out.  What’s the meaning of this…?  H-He…! \t\t\t\t\tWhat in the world…?!  W-What is he…?!  It can’t be… This Chakra!  T-That’s…impossible!  No way! His Chakra Points\\Nhave been pressed!  This Chakra…\\Nlt’s the Nine-Tailed Fox\'s, no doubt…  When did he master\\Nthe Nine-Tailed Fox’s Chakra…?!  Here I go!  It’s twisting…  What’s that?!\\Nls that even C ...

# %%
script_sentences=sent_tokenize(script)

# %%
script_sentences[:3]
# Out:
# ["Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength  Even if you get lost, let’s start walking  One more time  Are you really happy  when you're always meeting\\Nto someone's expectations?",
#  'Even if you change to\\Nwho you really wanna be  Will you always have a great smile?',
#  "Dreaming of only “the beginning,”\\NI wake up  and someday, I'll live on my own."]

# %%
#Batch Sentences
sentence_batch_size=20
script_batches_list=[]
for index in range(0,len(script_sentences),sentence_batch_size):
  sent=" ".join(script_sentences[index:index+sentence_batch_size])
  script_batches_list.append(sent)

# %%
script_batches_list
# Out:
# ["Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength  Even if you get lost, let’s start walking  One more time  Are you really happy  when you're always meeting\\Nto someone's expectations? Even if you change to\\Nwho you really wanna be  Will you always have a great smile? Dreaming of only “the beginning,”\\NI wake up  and someday, I'll live on my own. Yes, precious things are never in shape  You never know what it is\\Nwhen you get it or lose it  Yeah, turn your sadness into kindness,\\Nyour uniqueness into strength  Even if you get lost,\\Nlet's start walking  One more time  Your destiny is to lose to me.\\NFor sure. You don’t know until you try! Your father was killed a long time ago  and I don’t know the extent\\Nof the pain you’ve felt…  But it’s a huge mistake for you to think\\Nthat has determined your entire destiny! You’re hopeless…  Proctor…it’s over. You failure…  A Failure's True Power  Don’t…run away. I won’t…run…  I’ll…stand by my own words…  That’s my Ninja Way! I’ll…  stand…  by my own…  words! That’s my…Ninja Way…  I think I’ve heard that line before…  You with your destiny stuff…  I won’t lose…  to a jerk with cold feet like you,\\Nno matter what! Naruto…  A brat who knows nothing\\Nshouldn’t lecture arrogantly! People are born burdened with\\Nan inherent destiny that they cannot defy. Neji…live…  You’re a man who is blessed\\Nwith Hyuga ability  more than anyone in the family…  I wanted you…to be born\\Ninto the head family…  You can’t possibly understand  the destiny of being burdened with\\Na mark that cannot be wiped off for life! Yeah…  I do understand it. So…what of it? This brat! Don’t be acting cool…  It’s not just you who’s special! Hinata was also…\\Nsuffering the same as you! Even though she’s the head family,\\Nnot being acknowledged as such…  trying desperately to change herself…  She fought you while coughing\\Nup blood with that in mind!",
#  "You too! The branch family that\\Nprotects the head family…  Doing all that to Hinata\\Njust because it’s an exam. In actuality, you were just as frantic  in attempting to go\\Nagainst destiny, right? Vitality has returned to Hinata’s face! Just what I’d expect of\\Nthe Anbu Black Ops…  She'll be okay. Now she needs bed rest. Your 64 Chakra Points are now shut…  How are you, who can’t use Chakra\\Nfor awhile, planning to fight? At the end of the day,  you and Miss Hinata have\\Nthe same destiny! Shut up! With your Byakugan, labeling people\\Nand talking like you understand! Then…show me whether what\\Nyou’re saying is true or not. I will! I’ll defeat you no matter\\Nwhat and prove that to you! Dang it… Dang it! That being said, I don’t feel Chakra at all. It feels like when I used up\\Nmy Chakra in the training. You possess two kinds of Chakra…  You must extract and utilize, at any time,  the other huge Chakra that\\Nhas rested inside you from the start…  That’s it. The Nine-Tailed Fox Chakra…\\NI’ll use that…  Stinking fox… \t\t\t\t\tHelp me out! This is as far as the talking goes. Proctor… I’m going to fight with\\Nthe intent to kill him!",
#  'If you’re going to stop me,\\Nplease feel free. Jeez. Didn’t I tell you it is pointless? This time, I really can’t lose! I’ll win no matter what! It’s futile…I pressed the Chakra Points…  No matter what…  Oh, yeah! Be sure to come\\Nwatch me kick that Neji’s butt! A failure beats down\\Na genius with effort…  His opponent might be me…  But even if that’s you, Naruto,\\Nno hard feelings. Why do you try to go against\\Nyour destiny that much? Because I was called…  a failure! No, no way! Chakra is seeping out. What’s the meaning of this…? H-He…! What in the world…?! W-What is he…?! It can’t be… This Chakra! T-That’s…impossible! No way! His Chakra Points\\Nhave been pressed!',
#  "This Chakra…\\Nlt’s the Nine-Tailed Fox's, no doubt…  When did he master\\Nthe Nine-Tailed Fox’s Chakra…?! Here I go! It’s twisting…  What’s that? !\\Nls that even Chakra?! Awesome power.\\NMore so than during the training…  I feel it! Rotation! What?! His speed’s gone up!\\NWhat in the world is going on?! You! You’re confident in close combat, right?! You’re going to become the Hokage…? I don’t… think so. Only a very small percentage of\\NNinja are chosen to be the Hokage! Look more at reality! Those who become the Hokage\\Nare born with destiny. It’s not something you become\\Nby trying to become it. It’s determined by destiny. People must live within\\Ntheir different respective currents  that can’t be gone against. I don’t know what the\\NHyuga destiny of hatred is! But if you’re going to say it’s futile,\\Nyou don’t have to do anything!",
#  'This is bad! I must use the Rotation! After I become the Hokage…  I’ll change Hyuga! What Chakra…  That kid showed some enormous strength…  The Hyuga kid is probably…  Say! Which one’s Naruto?! I don’t know, either! Neji’s Rotation is a technique\\Nwhere the body rotates,  and dodges and\\Nrepels the opponent’s Chakra! It looks like there was\\Nmore damage done to Naruto  since he plunged right into the Rotation. There’s no Genin that can beat Neji…  But Naruto, you’re incredible…  To think you’d force him this far…  Failure boy…\\NSorry, but this is the reality…  Now this is really the en…  My body…  So he left a Shadow clone in the hole\\Nand spotted a chance to win, huh…  Believing in victory,\\Nthinking about what’s next  and acting even when getting\\Nknocked around, huh…  The power of believing in oneself. That becomes the power\\Nto change destiny…  He knows this…\\NAnd he’s a natural to boot. In those conditions,  you used the Shadow Clone Jutsu\\Njust like that…  The Ninjutsu that you’re good at, huh? I was careless…  I’ve…failed the graduation\\Nexam three times…  As luck would have it,  the Ninjutsu tests that appeared\\Non the graduation exam were always…  infallibly the Ninjutsu I stunk at. Clone Jutsu was the Ninjutsu…\\NI stunk at. Don’t be whining about boring stuff\\Nlike destiny and what not,  and how it can’t be changed! Because unlike me…\\Nyou’re not a failure. Winner of this match is Naruto Uzumaki. One! First, Tyson jumps and slamdunks  Two! He kisses and hugs everyone\\Nrandomly and says “I LOVE YOU”  Three! Masala masters Yoga\\Nbut hates curry  Four!',
#  'Sanchez is a lousy bullfighter. Ole! All over the world, the sky’s smiling,\\Nso look up and smile too  Oh yeah! Oh yeah! Oh yeah!\\NFight! Fight! Fight! One! Bodimahattaya-san devotes\\Nhis time for digging black ships  Two! Peking Duck, Action Scene,\\NChen Lee speeds around on his bike  Three! Popo loves to polish his Coteka  Four! Japanese people,\\Nnow lend me you hand! All over the world, the sky’s smiling,\\Nso look up and smile too  Oh yeah! Oh yeah! Oh yeah!\\NFight! Fight! Fight! All over the world, the sky’s smiling,\\Nso look up and smile too  Oh yeah! Oh yeah! Oh yeah!\\NFight!',
#  'Fight! Fight! Yahoo! I\'ve won! I\'ve won! Hey Naruto…  Don\'t you think I was so cool?! Don\'t get so carried away! Sakura…? Sasuke hasn\'t arrived here yet. What\'s up with that kid,\\Nmaking Sakura worry so much? Nex time, "Hit it or Quit it:\\NThe Final Rounds Get Complicated!"']

# %%
theme_output=theme_classifier(
    script_batches_list[:2],
    theme_list,
    multi_label=True
)

# %%
# Wrangle Output
# battle: [0.514899498,0.2156498]
themes={}
for output in theme_output:
  for label,score in zip(output['labels'],output['scores']):
    if label not in themes:
      themes[label]=[]
    themes[label].append(score)

# %%
import numpy as np

# %%
themes={key:np.mean(np.array(value)) for key,value in themes.items()}

# %%
themes
# Out:
# {'self development': 0.8777180910110474,
#  'sacrifice': 0.8917644023895264,
#  'dialogue': 0.9312507212162018,
#  'betrayal': 0.9295525252819061,
#  'battle': 0.787899523973465,
#  'friendship': 0.29046486504375935,
#  'love': 0.27664252184331417,
#  'hope': 0.3169528990983963}

# %%
def get_themes_inference(script):
  script_sentences=sent_tokenize(script)
  sentence_batch_size=20
  script_batches_list=[]
  for index in range(0,len(script_sentences),sentence_batch_size):
    sent=" ".join(script_sentences[index:index+sentence_batch_size])
    script_batches_list.append(sent)

  # Run Model
  theme_output=theme_classifier(
      script_batches_list,
      theme_list,
      multi_label=True
  )
  #wrangle output
  themes={}
  for output in theme_output:
    for label,score in zip(output['labels'],output['scores']):
      if label not in themes:
        themes[label]=[]
      themes[label].append(score)

  themes={key:np.mean(np.array(value)) for key,value in themes.items()}
  return themes

# %%
df=df.head(2)

# %%
df
# Out:
#    episode                                             script
# 0       62  Yeah, turn your sadness into kindness,\Nyour u...
# 1      114  Connecting old words\Nthat have been used up  ...

# %%
output_themes=df['script'].apply(get_themes_inference)

# %%
output_themes
# Out:
# 0    {'self development': 0.6297365591994354, 'sacr...
# 1    {'battle': 0.7392865214496851, 'friendship': 0...
# Name: script, dtype: object

# %%
theme_df=pd.DataFrame(output_themes.tolist())

# %%
theme_df
# Out:
#    self development  sacrifice  dialogue  betrayal    battle  friendship  \
# 0          0.629737   0.669970  0.693673  0.538314  0.845163    0.189756
# 1          0.644001   0.781588  0.909088  0.613735  0.739287    0.506531
#
#        love      hope
# 0  0.189148  0.278790
# 1  0.157669  0.291027

# %%
df[theme_df.columns]=theme_df
df
# Out:
#    episode                                             script  \
# 0       62  Yeah, turn your sadness into kindness,\Nyour u...
# 1      114  Connecting old words\Nthat have been used up  ...
#
#    self development  sacrifice  dialogue  betrayal    battle  friendship  \
# 0          0.629737   0.669970  0.693673  0.538314  0.845163    0.189756
# 1          0.644001   0.781588  0.909088  0.613735  0.739287    0.506531
#
#        love      hope
# 0  0.189148  0.278790
# 1  0.157669  0.291027
